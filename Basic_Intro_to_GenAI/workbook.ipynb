# %% [markdown]
# # Workbook: Introduction to Generative AI & Chatbots
#
# ### How to Use This Workbook
# - Read each question carefully
# - Answer in the cell provided (code or text)
# - There are no wrong attempts — the goal is to **think and explore!**
#
# ---

# %% [markdown]
# ## Part 1: Understanding Chatbots & LLMs
#
# ---

# %% [markdown]
# ### Question 1: What is a Chatbot?
#
# Fill in the blanks below in your own words:

# %% [markdown]
# **A chatbot is:** *(write your answer here)*
#
# **One chatbot I have seen or used in Kenya is:** *(write your answer here)*
#
# **The difference between a rule-based chatbot and an AI chatbot is:** *(write your answer here)*

# %% [markdown]
# ---
# ### Question 2: Match the LLM to its Creator
#
# Draw a line (or write the matching letter) connecting the LLM to the company that made it:
#
# | LLM | | Company |
# |-----|---|--------|
# | GPT-4o | ↔ | A. Google |
# | Llama 3 | ↔ | B. OpenAI |
# | Gemma | ↔ | C. Meta (Facebook) |
# | Mistral | ↔ | D. Mistral AI |
#
# **Write your answers here:**
# - GPT-4o → ___
# - Llama 3 → ___
# - Gemma → ___
# - Mistral → ___

# %% [markdown]
# ---
# ### Question 3: True or False?
#
# Mark each statement **True** or **False** and explain WHY in one sentence:
#
# 1. "LLMs always give correct answers."
#    - **True / False:** ___
#    - **Why:** *(write here)*
#
# 2. "Ollama requires an internet connection to chat with an AI."
#    - **True / False:** ___
#    - **Why:** *(write here)*
#
# 3. "The `system` role in a chat message gives the AI its personality."
#    - **True / False:** ___
#    - **Why:** *(write here)*
#
# 4. "An API key is like a public username — you can share it freely."
#    - **True / False:** ___
#    - **Why:** *(write here)*

# %% [markdown]
# ---
# ### Question 4: How Does an LLM Learn?
#
# Put the steps of LLM training in the correct order by numbering them 1-4:
#
# - ___ Fine-tune the model with human feedback to make it helpful and safe
# - ___ Collect massive amounts of text from the internet and books
# - ___ Repeat billions of times until the model predicts text accurately
# - ___ Train the model to predict the next word in a sentence

# %% [markdown]
# ---
# ## Part 2: Using Ollama in Python
#
# ---

# %% [markdown]
# ### Question 5 — Fix the Bug!
#
# The code below has **3 mistakes**. Find them and fix them.
#
# Hints:
# - Check the import
# - Check the role names
# - Check how the reply is accessed

# %%
# BUGGY CODE — find and fix the 3 mistakes!

import olama   # Bug 1: ???

response = ollama.chat(
    model="llama3.2",
    messages=[
        {"role": "Student",  "content": "What is Mount Kenya?"}  # Bug 2: ???
    ]
)

print(response["text"]["content"])   # Bug 3: ???

# %%
# FIXED CODE — write the corrected version here

# %% [markdown]
# ---
# ### Question 6 — Fill in the Blanks
#
# Complete the code to create an AI tutor named **Aisha** who is an expert in Biology:

# %%
import ollama

# Fill in the blanks (replace ??? with the correct values)

system_message = "You are ???, a friendly Biology tutor for Kenyan students aged 12-15."

response = ollama.???(                   # which ollama function do we call?
    model="???",                         # which model?
    messages=[
        {"role": "???",  "content": system_message},     # system or user?
        {"role": "user", "content": "What is a cell?"}
    ]
)

print(response["???"]["content"])        # how do we get the reply?

# %% [markdown]
# ---
# ### Question 7 — Write From Scratch!
#
# Write a Python program that:
# 1. Creates an AI food expert called **"Chef Otieno"**
# 2. The AI's specialty is traditional Kenyan recipes
# 3. Asks the AI: *"How do I make githeri?"*
# 4. Prints the answer
#
# You must write ALL the code yourself — no copying from the notebook!

# %%
# Question 7 — Write your code here

# %% [markdown]
# ---
# ### Question 8 — Explain the Conversation History
#
# Look at this conversation history list:
#
# ```python
# history = [
#     {"role": "system",    "content": "You are a Kenyan geography expert."},
#     {"role": "user",      "content": "How many counties does Kenya have?"},
#     {"role": "assistant", "content": "Kenya has 47 counties."},
#     {"role": "user",      "content": "Which county has the largest area?"},
# ]
# ```
#
# Answer these questions:
#
# 1. How many messages has the **user** sent so far? ___
# 2. What role does the **first message** have? ___
# 3. Why do we keep the **entire history** when sending the next message? *(write in your own words below)*

# %% [markdown]
# **Your answer to question 3:**
# *(write here)*

# %% [markdown]
# ---
# ## Part 3: Streamlit Chatbot
#
# ---

# %% [markdown]
# ### Question 9 — Streamlit Concepts
#
# Match each Streamlit function to what it does:
#
# | Function | | What it does |
# |----------|-|--------------|
# | `st.title()` | ↔ | A. Shows an input box at the bottom of the chat |
# | `st.chat_input()` | ↔ | B. Displays text as the title of the page |
# | `st.chat_message()` | ↔ | C. Creates a message bubble (user or AI) |
# | `st.session_state` | ↔ | D. Remembers data between interactions |
# | `st.sidebar` | ↔ | E. Creates a side panel with extra info |
#
# **Write your answers here:**
# - `st.title()` → ___
# - `st.chat_input()` → ___
# - `st.chat_message()` → ___
# - `st.session_state` → ___
# - `st.sidebar` → ___

# %% [markdown]
# ---
# ### Question 10 — Design Your Chatbot!
#
# You are going to design (plan) your own chatbot before building it.
# Fill in the details below:

# %% [markdown]
# **My Chatbot Design Plan**
#
# | Design Element | My Choice |
# |---------------|----------|
# | **Chatbot Name** | *(e.g., Zawadi)* |
# | **Chatbot Personality** | *(e.g., friendly, formal, funny)* |
# | **Subject / Area of Help** | *(e.g., Maths tutor, Swahili teacher)* |
# | **Target Users** | *(e.g., Form 1 students)* |
# | **Greeting message** | *(what does it say first?)* |
# | **One example question it should answer well** | *(e.g., How do I solve quadratic equations?)* |

# %% [markdown]
# ---
# ### Question 11 — Build It!
#
# Using your design from Question 10, open the file `ollama_chatbot_app.py` and customize it.
#
# **Checklist:**
# - [ ] Changed the chatbot's title
# - [ ] Updated the system message with the correct name and personality
# - [ ] Added a sidebar with the chatbot name and your name as developer
# - [ ] Added a "Clear Chat" button to the sidebar
# - [ ] Ran the app with `streamlit run ollama_chatbot_app.py`
# - [ ] Tested it with at least 3 questions
#
# When done, write below:
# 1. What worked well?
# 2. What surprised you?
# 3. What would you add if you had more time?

# %% [markdown]
# **My Reflection:**
# *(write here)*

# %% [markdown]
# ---
# ## Part 4: API Key Safety & Deploying Your Chatbot
#
# ---

# %% [markdown]
# ---
# ### Question 12 — API Key Safety: True or False?
#
# Mark each statement **True** or **False** and explain WHY in one sentence:
#
# 1. "It is safe to write your OpenAI API key directly in your Python file and upload it to GitHub."
#    - **True / False:** ___
#    - **Why:** *(write here)*
#
# 2. "`st.secrets` reads your API key from a file called `secrets.toml` inside the `.streamlit` folder."
#    - **True / False:** ___
#    - **Why:** *(write here)*
#
# 3. "The `.gitignore` file tells Git which files to upload to GitHub."
#    - **True / False:** ___
#    - **Why:** *(write here)*
#
# 4. "After switching to `st.secrets`, your Python code file is now safe to share because it contains no key."
#    - **True / False:** ___
#    - **Why:** *(write here)*

# %% [markdown]
# ---
# ### Question 13 — Spot the Problem!
#
# Look at Wanjiku's code below. She wants to deploy her chatbot to Streamlit Cloud and share it with her class.
#
# ```python
# # Wanjiku's chatbot — openai_chatbot_app.py
# import streamlit as st
# from openai import OpenAI
#
# api_key = "sk-proj-wanjiku1234abcxyz"    # Wanjiku's real API key
#
# client = OpenAI(api_key=api_key)
# st.title("Wanjiku's Chatbot")
# ```
#
# She uploads this file to GitHub so she can deploy it.
#
# **Answer these questions:**
#
# 1. What is the problem with Wanjiku's code? *(write here)*
#
# 2. What could happen if someone finds her API key on GitHub? *(write here)*
#
# 3. Rewrite the ONE line that needs to change to make it safe: *(write here)*
#
# ```python
# # Fix this line:
# api_key = "sk-proj-wanjiku1234abcxyz"
#
# # Your fixed version:
#
# ```

# %% [markdown]
# ---
# ### Question 14 — Fill in the Blanks: `secrets.toml`
#
# Complete the `secrets.toml` file and the Python code that reads from it:
#
# **Part A — The secrets file** (fill in the blanks):
# ```toml
# # .streamlit/secrets.toml
# ??? = "sk-your-api-key-here"
# ```
#
# **Part B — The Python code** (fill in the blanks):
# ```python
# import streamlit as ???
# from openai import OpenAI
#
# # Read the key safely from secrets.toml
# api_key = st.???["???"]
#
# client = OpenAI(api_key=???)
# ```
#
# **Write your completed versions below:**

# %%
# Question 14 — Write your completed secrets.toml and Python code here as comments

# secrets.toml:
# ??? = "sk-your-api-key-here"

# Python code:
# api_key = st.???["???"]
# client = OpenAI(api_key=???)

# %% [markdown]
# ---
# ### Question 15 — What Goes in Each File?
#
# Draw a line (or write the matching letter) connecting each file to its purpose:
#
# | File | | Purpose |
# |------|-|---------|
# | `requirements.txt` | ↔ | A. Lists files that Git must NOT upload to GitHub |
# | `.gitignore` | ↔ | B. Stores your secret API key on your laptop |
# | `.streamlit/secrets.toml` | ↔ | C. Lists Python libraries Streamlit Cloud must install |
#
# **Write your answers here:**
# - `requirements.txt` → ___
# - `.gitignore` → ___
# - `.streamlit/secrets.toml` → ___
#
# **Write what you would put inside `requirements.txt` for a chatbot that uses Streamlit and OpenAI:**

# %% [markdown]
# ---
# ### Question 16 — Order the Deployment Steps
#
# Otieno wants to deploy his Streamlit chatbot to the internet.
# Put his steps in the correct order by numbering them 1–6:
#
# - ___ Share the live link (e.g., `otieno-chatbot.streamlit.app`) with his classmates
# - ___ Add his API key in the Streamlit Cloud **Secrets** panel
# - ___ Create `requirements.txt` and `.gitignore` in his project folder
# - ___ Push his code to a GitHub repository (without `secrets.toml`)
# - ___ Switch `api_key = "sk-..."` to `api_key = st.secrets["OPENAI_API_KEY"]` in his code
# - ___ Go to share.streamlit.io, connect his GitHub repo, and click Deploy

# %% [markdown]
# ---
# ### Question 17 — Local vs Deployed: Fill the Table
#
# Complete the comparison table below:
#
# | | On Your Laptop | Deployed on Streamlit Cloud |
# |-|----------------|-----------------------------|
# | **Who can use it?** | Only you | ??? |
# | **AI model used** | ??? (free, offline) | OpenAI GPT (cloud) |
# | **API key stored in** | `.streamlit/secrets.toml` | ??? |
# | **Needs internet to chat?** | ❌ No (with Ollama) | ??? |
# | **Cost** | Free | ??? |
#
# **Write your completed table here:**

# %% [markdown]
# ---
# ### Question 18 — Deploy Your Chatbot!
#
# Using your chatbot from Question 11, go through the full deployment checklist:
#
# **Prepare your files:**
# - [ ] Updated `openai_chatbot_app.py` to use `st.secrets["OPENAI_API_KEY"]` instead of a hardcoded key
# - [ ] Ran the helper cells in the notebook to create `requirements.txt` and `.gitignore`
# - [ ] Opened `.streamlit/secrets.toml` and added your real API key
# - [ ] Tested the app locally with `streamlit run openai_chatbot_app.py`
#
# **Deploy:**
# - [ ] Created a GitHub account (or logged in)
# - [ ] Created a new GitHub repository and uploaded your files
# - [ ] Confirmed `secrets.toml` is **not** in the repository
# - [ ] Signed in to [share.streamlit.io](https://share.streamlit.io) with GitHub
# - [ ] Connected the repository and deployed the app
# - [ ] Added your API key in the Streamlit Cloud Secrets panel
#
# **Share:**
# - [ ] Got a live URL from Streamlit Cloud
# - [ ] Tested the deployed chatbot from a browser
# - [ ] Shared the link with a classmate and had them test it
#
# **Write your live URL here when done:**

# %% [markdown]
# **My live chatbot URL:** *(paste your link here)*
#
# **What was the hardest part of deploying?** *(write here)*
#
# **What did your classmate say when they tested it?** *(write here)*

# %% [markdown]
# ---
# ## Bonus Challenge — Build a Swahili Chatbot! 🇰🇪
#
# Modify the Ollama chatbot so that:
# 1. The system message tells the AI to respond in **Swahili**
# 2. The UI title is in Swahili (e.g., *"Msaidizi Wangu"* = My Assistant)
# 3. The input placeholder says *"Andika ujumbe wako hapa..."* (Type your message here)
#
# Test it by asking: *"Nikusaidie nini leo?"* (How can I help you today?)
#
# **Hint:** You can pass a placeholder to `st.chat_input()` like this:
# ```python
# st.chat_input("Andika ujumbe wako hapa...")
# ```

# %%
# Use this cell to write notes or plan your changes before editing the .py file
# What will your system message say?

my_system_message_plan = """
Write your system message plan here...
"""

print(my_system_message_plan)

# %% [markdown]
# ---
# ## Well Done! 🎉
#
# You have completed the workbook on Introduction to Generative AI!
#
# You can now:
# - ✅ Explain what chatbots and LLMs are
# - ✅ Use Ollama to run AI on your laptop for free
# - ✅ Write Python code to talk to an LLM
# - ✅ Build a chatbot web app with Streamlit
# - ✅ Store API keys safely using `st.secrets` — never in your code!
# - ✅ Deploy a chatbot to the internet using Streamlit Community Cloud
# - ✅ Share your chatbot with anyone using a public link
#
# **Next Steps:**
# - Explore more Ollama models (`ollama pull mistral`)
# - Try building a chatbot for a specific use case (homework helper, recipe suggester, story creator)
# - Learn about prompt engineering — how to write better system messages to get better answers
# - Add more features to your deployed app (e.g., a dropdown to choose the AI's personality!)
